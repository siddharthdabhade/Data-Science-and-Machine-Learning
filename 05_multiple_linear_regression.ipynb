# %% [markdown]
# # Multiple Linear Regression
#
# Build regression with multiple predictors and compute VIF.

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
