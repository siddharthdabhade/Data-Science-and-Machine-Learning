# %% [markdown]
# # Working with Various File Formats
#
# Read CSV, Excel, SQL, XML examples (local samples).

# %%
import pandas as pd
df = pd.read_csv('../datasets/bank_marketing.csv')
print(df.head())
