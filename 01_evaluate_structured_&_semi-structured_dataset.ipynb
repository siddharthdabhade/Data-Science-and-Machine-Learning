# %% [markdown]
# # Evaluate Structured & Semi-Structured Dataset
#
# Load CSV and JSON, normalize nested JSON and compare schemas.

# %%
import pandas as pd

df_csv = pd.read_csv('../datasets/house_prices.csv')
print(df_csv.head())
