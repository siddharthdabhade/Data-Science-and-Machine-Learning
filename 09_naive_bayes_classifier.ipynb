# %% [markdown]
# # Naive Bayes Classifier
#
# Text classification using SMS dataset sample.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
